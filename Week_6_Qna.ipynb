# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_excel("C:/Users/imins/Downloads/Dataset_w6.xlsx")
data
# Out:
#                                 country             Region  \
# 0                           Afghanistan       SouthernAsia
# 1                               Albania     SouthernEurope
# 2                               Algeria     NorthernAfrica
# 3                                Angola       MiddleAfrica
# 4                   Antigua and Barbuda          Caribbean
# ..                                  ...                ...
# 191  Venezuela (Bolivarian Republic of)       SouthAmerica
# 192                            Viet Nam  South-easternAsia
# 193                               Yemen        WesternAsia
# 194                              Zambia      EasternAfrica
# 195                            Zimbabwe      EasternAfrica
#
#      Surface area (km2)  Population in thousands (2017)  \
# 0              652864.0                         35530.0
# 1               28748.0                          2930.0
# 2             2381741.0                         41318.0
# ...

# %% [markdown]
# # 1. Find out how many countries are there in the dataset.

# %%
print("There are",data['country'].count(),"countries in the dataset ")
# Out:
# There are 196 countries in the dataset

# %% [markdown]
# # 2. Examine the data by using visualizations

# %%
max1= data.nlargest(10,'Surface area (km2)')
max1
# Out:
#                       country           Region  Surface area (km2)  \
# 145        Russian Federation    EasternEurope          17098246.0
# 32                     Canada  NorthernAmerica           9984670.0
# 187  United States of America  NorthernAmerica           9833517.0
# 39                      China      EasternAsia           9600000.0
# 23                     Brazil     SouthAmerica           8515767.0
# 7                   Australia          Oceania           7692060.0
# 82                      India     SouthernAsia           3287263.0
# 5                   Argentina     SouthAmerica           2780400.0
# 92                 Kazakhstan      CentralAsia           2724902.0
# 2                     Algeria   NorthernAfrica           2381741.0
#
#      Population in thousands (2017)  GDP per capita (current US$)  \
# 145                        143990.0                        9243.3
# 32                          36624.0                       43205.6
# ...

# %% [markdown]
# ## Top 10 countries based on surface area

# %%
m = max1['Surface area (km2)']

# %%
plt.pie(m,labels=max1['country'])
plt.title('Top 10 countries based on surface area')
plt.show()

# %%
max2 = data.nsmallest(10,'Population in thousands (2017)')
max2
# Out:
#                     country           Region  Surface area (km2)  \
# 118              Montserrat        Caribbean               103.0
# 181                  Tuvalu        Polynesia                26.0
# 43             Cook Islands        Polynesia               236.0
# 133                   Palau       Micronesia               459.0
# 24   British Virgin Islands        Caribbean               151.0
# 111        Marshall Islands       Micronesia               181.0
# 147   Saint Kitts and Nevis        Caribbean               261.0
# 72                Greenland  NorthernAmerica           2166086.0
# 18                  Bermuda  NorthernAmerica                53.0
# 33           Cayman Islands        Caribbean               264.0
#
#      Population in thousands (2017)  GDP per capita (current US$)  \
# 118                             5.0                       11553.4
# 181                            11.0                        3362.4
# ...

# %% [markdown]
# ## Smallest 10 countries based on population

# %%
c = max2['country']
d = max2['Population in thousands (2017)']

# %%
plt.bar(c,d)
plt.xticks(rotation=70)
plt.title('Smallest 10 countries based on population')
plt.xlabel('Country name')
plt.ylabel('Population in thousands')
plt.show()

# %% [markdown]
# # 3. Find out how many countries with respect to the region are availablein the dataset

# %%
dt = data[['country','Region']]

# %%
dt
# Out:
#                                 country             Region
# 0                           Afghanistan       SouthernAsia
# 1                               Albania     SouthernEurope
# 2                               Algeria     NorthernAfrica
# 3                                Angola       MiddleAfrica
# 4                   Antigua and Barbuda          Caribbean
# ..                                  ...                ...
# 191  Venezuela (Bolivarian Republic of)       SouthAmerica
# 192                            Viet Nam  South-easternAsia
# 193                               Yemen        WesternAsia
# 194                              Zambia      EasternAfrica
# 195                            Zimbabwe      EasternAfrica
#
# [196 rows x 2 columns]

# %%
gp = dt.groupby('Region')['country'].count()

# %%
print(gp)
# Out:
# Region
# Caribbean            16
# CentralAmerica        8
# CentralAsia           5
# EasternAfrica        17
# EasternAsia           7
# EasternEurope        10
# Melanesia             5
# Micronesia            4
# MiddleAfrica          9
# NorthernAfrica        5
# NorthernAmerica       4
# NorthernEurope       10
# Oceania               2
# Polynesia             5
# South-easternAsia    11
# SouthAmerica         12
# SouthernAfrica        5
# SouthernAsia          9
# SouthernEurope       12
# WesternAfrica        15
# WesternAsia          18
# WesternEurope         7
# Name: country, dtype: int64

# %% [markdown]
# # 4. On average which region has the highest

# %% [markdown]
# ## a. GDP per capita (current US$)

# %%
dt1 = data[['Region','GDP per capita (current US$)']]

gp1 = dt1.groupby('Region')['GDP per capita (current US$)'].mean()

print(gp1)
# Out:
# Region
# Caribbean            15135.562500
# CentralAmerica        6348.137500
# CentralAsia           4329.880000
# EasternAfrica         2088.852941
# EasternAsia          27967.614286
# EasternEurope         9292.490000
# Melanesia             9261.960000
# Micronesia            5008.300000
# MiddleAfrica          3928.833333
# NorthernAfrica        3934.960000
# NorthernAmerica      57659.000000
# NorthernEurope       42098.220000
# Oceania              44823.250000
# Polynesia             8686.520000
# South-easternAsia    10299.027273
# SouthAmerica          8499.775000
# SouthernAfrica        4191.900000
# SouthernAsia          2968.400000
# SouthernEurope       14462.741667
# WesternAfrica         1013.140000
# WesternAsia          17013.938889
# WesternEurope        55387.128571
# Name: GDP per capita (current US$), dtype: float64

# %%
print(gp1.idxmax(),'has the highest GDP per capita (current US$) of',gp1.max())
# Out:
# NorthernAmerica has the highest GDP per capita (current US$) of 57659.0

# %% [markdown]
# ## b. International trade: Imports (million US$)

# %%
dt2 = data[['Region','International trade: Imports (million US$)']]

gp2 = dt2.groupby('Region')['International trade: Imports (million US$)'].mean()

print(gp2)
# Out:
# Region
# Caribbean              3057.312500
# CentralAmerica        57031.500000
# CentralAsia           12063.400000
# EasternAfrica          4726.176471
# EasternAsia          451995.000000
# EasternEurope         85243.900000
# Melanesia              2896.400000
# Micronesia               99.000000
# MiddleAfrica           4381.222222
# NorthernAfrica        35034.400000
# NorthernAmerica      663552.250000
# NorthernEurope       113407.200000
# Oceania              112914.500000
# Polynesia               432.000000
# South-easternAsia     98324.636364
# SouthAmerica          32885.666667
# SouthernAfrica        18005.600000
# SouthernAsia          58199.333333
# SouthernEurope        76666.666667
# WesternAfrica          4898.333333
# WesternAsia           46025.555556
# WesternEurope        407498.428571
# Name: International trade: Imports (million US$), dtype: float64

# %%
print(gp2.idxmax(),'has the highest International trade: Imports (million US$) of',gp2.max())
# Out:
# NorthernAmerica has the highest International trade: Imports (million US$) of 663552.25

# %% [markdown]
# # 5. Find out which region has more consistent with respect to GDP percapita (current US$)

# %%
dt3 = data[['Region','GDP per capita (current US$)']]

gp3 = dt3.groupby('Region')['GDP per capita (current US$)'].std()

print(gp3)
# Out:
# Region
# Caribbean            14579.371326
# CentralAmerica        4180.440883
# CentralAsia           4152.215490
# EasternAfrica         3716.131770
# EasternAsia          27485.120923
# EasternEurope         5415.488739
# Melanesia            13855.842686
# Micronesia            4820.669694
# MiddleAfrica          5274.846281
# NorthernAfrica         974.706575
# NorthernAmerica      25749.619445
# NorthernEurope       20671.030185
# Oceania               9233.329638
# Polynesia             6956.250286
# South-easternAsia    16311.810656
# SouthAmerica          4273.707394
# SouthernAfrica        2177.551120
# SouthernAsia          2855.708179
# SouthernEurope        9541.703216
# WesternAfrica          815.095399
# WesternAsia          18812.151459
# WesternEurope        24770.467728
# Name: GDP per capita (current US$), dtype: float64

# %%
print(gp3.idxmin(),'has more consistent with respect to GDP percapita (current US$) of',gp3.min())
# Out:
# WesternAfrica has more consistent with respect to GDP percapita (current US$) of 815.0953991492564
